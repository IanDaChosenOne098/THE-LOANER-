# %%
import pandas as pd

# %%
data = pd.read_csv('Track.csv')

# %%
data = data.drop(['purchaser_type','ffiec_msa_md_median_fam_income','balloon_payment','business_or_commercial_purpose','combined_loan_to_value_ratio'],axis=1)

# %%
data = data.drop(['year','state_code','county_code','msa','census_tract','applicant_age_above_62','lender_credits','lien_status','occupancy_type','total_units'],axis=1)

# %%
data = data.drop(['tract_one_to_four_family_homes','tract_median_age_of_hu','tract_population','conforming_loan_limit','construction_method','discount_points'],axis=1)

# %%
data.head()
# Out:
#   applicant_age                                       race  \
# 0         45-54  Native Hawaiian or Other Pacific Islander
# 1         55-64                                      White
# 2         45-54                                      Asian
# 3         55-64                                      White
# 4         65-74                                      White
#
#                 ethnicity     sex  income debt_to_income_ratio  \
# 0      Hispanic or Latino    Male    26.0                 >60%
# 1  Not Hispanic or Latino   Joint   379.0                 >60%
# 2      Hispanic or Latino   Joint    86.0             41%-<46%
# 3      Hispanic or Latino  Female    25.0             36%-<41%
# 4  Not Hispanic or Latino    Male    33.0             20%-<30%
#
#    tract_minority_pop_percent  tract_to_msa_income_percentage  \
# 0                       84.39                            86.0
# 1                       24.86                           360.0
# ...

# %%
data = data.drop(['tract_to_msa_income_percentage','lei','aus','denial_reason'],axis=1)

# %%
data.head()
# Out:
#   applicant_age                                       race  \
# 0         45-54  Native Hawaiian or Other Pacific Islander
# 1         55-64                                      White
# 2         45-54                                      Asian
# 3         55-64                                      White
# 4         65-74                                      White
#
#                 ethnicity     sex  income debt_to_income_ratio  \
# 0      Hispanic or Latino    Male    26.0                 >60%
# 1  Not Hispanic or Latino   Joint   379.0                 >60%
# 2      Hispanic or Latino   Joint    86.0             41%-<46%
# 3      Hispanic or Latino  Female    25.0             36%-<41%
# 4  Not Hispanic or Latino    Male    33.0             20%-<30%
#
#    tract_minority_pop_percent  interest_rate  loan_amount     loan_type  \
# 0                       84.39            NaN      95000.0  Conventional
# 1                       24.86            NaN    3225000.0  Conventional
# ...

# %%
data = data.dropna(subset=['interest_rate','debt_to_income_ratio','total_loan_costs'], how='any')

# %%
data.head()
# Out:
#    applicant_age   race               ethnicity    sex  income  \
# 8          25-34  Asian  Not Hispanic or Latino  Joint   157.0
# 16         45-54  White  Not Hispanic or Latino  Joint   145.0
# 17         35-44  White  Not Hispanic or Latino   Male   105.0
# 18         25-34  White  Not Hispanic or Latino  Joint   142.0
# 19         25-34  White                   Joint  Joint   165.0
#
#    debt_to_income_ratio  tract_minority_pop_percent  interest_rate  \
# 8              46%-<50%                       24.00           4.50
# 16             20%-<30%                       30.84           3.75
# 17             20%-<30%                       46.45           3.99
# 18             30%-<36%                       32.84           3.75
# 19             20%-<30%                       94.53           4.25
#
#     loan_amount     loan_type  property_value  total_loan_costs  accepted
# 8      345000.0  Conventional        365000.0           3759.92       1.0
# ...

# %%
data.isna().sum()
# Out:
# applicant_age                   0
# race                            0
# ethnicity                       0
# sex                             0
# income                        596
# debt_to_income_ratio            0
# tract_minority_pop_percent      0
# interest_rate                   0
# loan_amount                     0
# loan_type                       0
# property_value                 89
# total_loan_costs                0
# accepted                        0
# dtype: int64

# %%
data = data.dropna(subset=['income','property_value'], how='any')

# %%
data.head(45)
# Out:
#    applicant_age                       race               ethnicity     sex  \
# 8          25-34                      Asian  Not Hispanic or Latino   Joint
# 16         45-54                      White  Not Hispanic or Latino   Joint
# 17         35-44                      White  Not Hispanic or Latino    Male
# 18         25-34                      White  Not Hispanic or Latino   Joint
# 19         25-34                      White                   Joint   Joint
# 20         35-44                      White  Not Hispanic or Latino   Joint
# 21         55-64                      White  Not Hispanic or Latino    Male
# 24         25-34                      White  Not Hispanic or Latino   Joint
# 25         45-54                      White  Not Hispanic or Latino    Male
# 26         25-34                      White  Not Hispanic or Latino  Female
# 27         25-34                      White  Not Hispanic or Latino    Male
# ...

# %%
data.isna().sum()
# Out:
# applicant_age                 0
# race                          0
# ethnicity                     0
# sex                           0
# income                        0
# debt_to_income_ratio          0
# tract_minority_pop_percent    0
# interest_rate                 0
# loan_amount                   0
# loan_type                     0
# property_value                0
# total_loan_costs              0
# accepted                      0
# dtype: int64

# %% [markdown]
# # Ordinal Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
dummies = pd.get_dummies(data['ethnicity'])
dummies.head()
# Out:
#     Free Form Text Only  Hispanic or Latino  Joint  Not Hispanic or Latino
# 8                     0                   0      0                       1
# 16                    0                   0      0                       1
# 17                    0                   0      0                       1
# 18                    0                   0      0                       1
# 19                    0                   0      1                       0

# %%
data = pd.concat([data, dummies], axis=1)
data.head()
# Out:
#    applicant_age   race               ethnicity    sex  income  \
# 8          25-34  Asian  Not Hispanic or Latino  Joint   157.0
# 16         45-54  White  Not Hispanic or Latino  Joint   145.0
# 17         35-44  White  Not Hispanic or Latino   Male   105.0
# 18         25-34  White  Not Hispanic or Latino  Joint   142.0
# 19         25-34  White                   Joint  Joint   165.0
#
#    debt_to_income_ratio  tract_minority_pop_percent  interest_rate  \
# 8              46%-<50%                       24.00           4.50
# 16             20%-<30%                       30.84           3.75
# 17             20%-<30%                       46.45           3.99
# 18             30%-<36%                       32.84           3.75
# 19             20%-<30%                       94.53           4.25
#
#     loan_amount     loan_type  property_value  total_loan_costs  accepted  \
# 8      345000.0  Conventional        365000.0           3759.92       1.0
# ...

# %%
data = data.drop(["ethnicity","Free Form Text Only"], axis=1)
data.head()
# Out:
#    applicant_age   race    sex  income debt_to_income_ratio  \
# 8          25-34  Asian  Joint   157.0             46%-<50%
# 16         45-54  White  Joint   145.0             20%-<30%
# 17         35-44  White   Male   105.0             20%-<30%
# 18         25-34  White  Joint   142.0             30%-<36%
# 19         25-34  White  Joint   165.0             20%-<30%
#
#     tract_minority_pop_percent  interest_rate  loan_amount     loan_type  \
# 8                        24.00           4.50     345000.0  Conventional
# 16                       30.84           3.75     335000.0            VA
# 17                       46.45           3.99     225000.0            VA
# 18                       32.84           3.75     405000.0            VA
# 19                       94.53           4.25     375000.0            VA
#
#     property_value  total_loan_costs  accepted  Hispanic or Latino  Joint  \
# 8         365000.0           3759.92       1.0                   0      0
# ...

# %%
df.rename(columns={'Joint': 'Hispanic_Latino_couple'}, inplace=True)
data.head()
# Out:
#    applicant_age   race    sex  income debt_to_income_ratio  \
# 8          25-34  Asian  Joint   157.0             46%-<50%
# 16         45-54  White  Joint   145.0             20%-<30%
# 17         35-44  White   Male   105.0             20%-<30%
# 18         25-34  White  Joint   142.0             30%-<36%
# 19         25-34  White  Joint   165.0             20%-<30%
#
#     tract_minority_pop_percent  interest_rate  loan_amount     loan_type  \
# 8                        24.00           4.50     345000.0  Conventional
# 16                       30.84           3.75     335000.0            VA
# 17                       46.45           3.99     225000.0            VA
# 18                       32.84           3.75     405000.0            VA
# 19                       94.53           4.25     375000.0            VA
#
#     property_value  total_loan_costs  accepted  Hispanic or Latino  \
# 8         365000.0           3759.92       1.0                   0
# ...

# %%
dummies = pd.get_dummies(data['race'])
dummies.head()
# Out:
#     2 or more minority races  American Indian or Alaska Native  Asian  \
# 8                          0                                 0      1
# 16                         0                                 0      0
# 17                         0                                 0      0
# 18                         0                                 0      0
# 19                         0                                 0      0
#
#     Black or African American  Free Form Text Only  Joint  \
# 8                           0                    0      0
# 16                          0                    0      0
# 17                          0                    0      0
# 18                          0                    0      0
# 19                          0                    0      0
#
#     Native Hawaiian or Other Pacific Islander  White
# 8                                           0      0
# 16                                          0      1
# ...

# %%
data = pd.concat([data, dummies], axis=1)
data.head()
# Out:
#    applicant_age   race    sex  income debt_to_income_ratio  \
# 8          25-34  Asian  Joint   157.0             46%-<50%
# 16         45-54  White  Joint   145.0             20%-<30%
# 17         35-44  White   Male   105.0             20%-<30%
# 18         25-34  White  Joint   142.0             30%-<36%
# 19         25-34  White  Joint   165.0             20%-<30%
#
#     tract_minority_pop_percent  interest_rate  loan_amount     loan_type  \
# 8                        24.00           4.50     345000.0  Conventional
# 16                       30.84           3.75     335000.0            VA
# 17                       46.45           3.99     225000.0            VA
# 18                       32.84           3.75     405000.0            VA
# 19                       94.53           4.25     375000.0            VA
#
#     property_value  ...  Hispanic_Latino_couple  Not Hispanic or Latino  \
# 8         365000.0  ...                       0                       1
# ...

# %%
data = data.drop(["race","Free Form Text Only"], axis=1)
data.head()
# Out:
#    applicant_age    sex  income debt_to_income_ratio  \
# 8          25-34  Joint   157.0             46%-<50%
# 16         45-54  Joint   145.0             20%-<30%
# 17         35-44   Male   105.0             20%-<30%
# 18         25-34  Joint   142.0             30%-<36%
# 19         25-34  Joint   165.0             20%-<30%
#
#     tract_minority_pop_percent  interest_rate  loan_amount     loan_type  \
# 8                        24.00           4.50     345000.0  Conventional
# 16                       30.84           3.75     335000.0            VA
# 17                       46.45           3.99     225000.0            VA
# 18                       32.84           3.75     405000.0            VA
# 19                       94.53           4.25     375000.0            VA
#
#     property_value  total_loan_costs  ...  Hispanic or Latino  \
# 8         365000.0           3759.92  ...                   0
# 16        365000.0           9047.48  ...                   0
# ...

# %%
dummies = pd.get_dummies(data['sex'])
dummies.head()
# Out:
#     Female  Joint  Male
# 8        0      1     0
# 16       0      1     0
# 17       0      0     1
# 18       0      1     0
# 19       0      1     0

# %%
data = pd.concat([data, dummies], axis=1)
data.head()
# Out:
#    applicant_age    sex  income debt_to_income_ratio  \
# 8          25-34  Joint   157.0             46%-<50%
# 16         45-54  Joint   145.0             20%-<30%
# 17         35-44   Male   105.0             20%-<30%
# 18         25-34  Joint   142.0             30%-<36%
# 19         25-34  Joint   165.0             20%-<30%
#
#     tract_minority_pop_percent  interest_rate  loan_amount     loan_type  \
# 8                        24.00           4.50     345000.0  Conventional
# 16                       30.84           3.75     335000.0            VA
# 17                       46.45           3.99     225000.0            VA
# 18                       32.84           3.75     405000.0            VA
# 19                       94.53           4.25     375000.0            VA
#
#     property_value  total_loan_costs  ...  2 or more minority races  \
# 8         365000.0           3759.92  ...                         0
# ...

# %%
data.rename(columns={'Joint': 'Couple'}, inplace=True)
data.head()
# Out:
#    applicant_age    sex  income debt_to_income_ratio  \
# 8          25-34  Joint   157.0             46%-<50%
# 16         45-54  Joint   145.0             20%-<30%
# 17         35-44   Male   105.0             20%-<30%
# 18         25-34  Joint   142.0             30%-<36%
# 19         25-34  Joint   165.0             20%-<30%
#
#     tract_minority_pop_percent  interest_rate  loan_amount     loan_type  \
# 8                        24.00           4.50     345000.0  Conventional
# 16                       30.84           3.75     335000.0            VA
# 17                       46.45           3.99     225000.0            VA
# 18                       32.84           3.75     405000.0            VA
# 19                       94.53           4.25     375000.0            VA
#
#     property_value  total_loan_costs  ...  2 or more minority races  \
# 8         365000.0           3759.92  ...                         0
# ...

# %%
data = data.drop(["sex"], axis=1)
data.head()
# Out:
#    applicant_age  income debt_to_income_ratio  tract_minority_pop_percent  \
# 8          25-34   157.0             46%-<50%                       24.00
# 16         45-54   145.0             20%-<30%                       30.84
# 17         35-44   105.0             20%-<30%                       46.45
# 18         25-34   142.0             30%-<36%                       32.84
# 19         25-34   165.0             20%-<30%                       94.53
#
#     interest_rate  loan_amount     loan_type  property_value  \
# 8            4.50     345000.0  Conventional        365000.0
# 16           3.75     335000.0            VA        365000.0
# 17           3.99     225000.0            VA        235000.0
# 18           3.75     405000.0            VA        395000.0
# 19           4.25     375000.0            VA        375000.0
#
#     total_loan_costs  accepted  ...  2 or more minority races  \
# 8            3759.92       1.0  ...                         0
# ...

# %%
data['debt_to_income_ratio'].unique()
# Out:
# array(['46%-<50%', '20%-<30%', '30%-<36%', '41%-<46%', '<20%', '36%-<41%',
#        '50%-60%', '>60%'], dtype=object)

# %%
debt_ratio_sort = ['46%-<50%', '20%-<30%', '30%-<36%', '41%-<46%', '<20%', '36%-<41%', '50%-60%', '>60%']
debt_ratio_enc = OrdinalEncoder(categories=[debt_ratio_sort])

# %%
data['debt_to_income_ratio'] = debt_ratio_enc.fit_transform(data['debt_to_income_ratio'].values.reshape(-1, 1))

# %%
data.head()
# Out:
#    applicant_age  income  debt_to_income_ratio  tract_minority_pop_percent  \
# 8          25-34   157.0                   0.0                       24.00
# 16         45-54   145.0                   1.0                       30.84
# 17         35-44   105.0                   1.0                       46.45
# 18         25-34   142.0                   2.0                       32.84
# 19         25-34   165.0                   1.0                       94.53
#
#     interest_rate  loan_amount     loan_type  property_value  \
# 8            4.50     345000.0  Conventional        365000.0
# 16           3.75     335000.0            VA        365000.0
# 17           3.99     225000.0            VA        235000.0
# 18           3.75     405000.0            VA        395000.0
# 19           4.25     375000.0            VA        375000.0
#
#     total_loan_costs  accepted  ...  2 or more minority races  \
# 8            3759.92       1.0  ...                         0
# ...

# %%
def encode_binary_variable(df, col, val_pos, val_neg):
    df[col] = df[col].replace({val_pos:1, val_neg:0})

# %%
data[data["loan_type"].str.contains("FHA")==False]
# Out:
#        applicant_age  income  debt_to_income_ratio  \
# 8              25-34   157.0                   0.0
# 16             45-54   145.0                   1.0
# 17             35-44   105.0                   1.0
# 18             25-34   142.0                   2.0
# 19             25-34   165.0                   1.0
# ...              ...     ...                   ...
# 136249         45-54    92.0                   5.0
# 136255         65-74    99.0                   6.0
# 136257         55-64   138.0                   2.0
# 136259         25-34    91.0                   2.0
# 136260         25-34   127.0                   2.0
#
#         tract_minority_pop_percent  interest_rate  loan_amount     loan_type  \
# 8                            24.00          4.500     345000.0  Conventional
# 16                           30.84          3.750     335000.0            VA
# 17                           46.45          3.990     225000.0            VA
# ...

# %%
data[data["loan_type"].str.contains("FSA")==False]
# Out:
#        applicant_age  income  debt_to_income_ratio  \
# 8              25-34   157.0                   0.0
# 16             45-54   145.0                   1.0
# 17             35-44   105.0                   1.0
# 18             25-34   142.0                   2.0
# 19             25-34   165.0                   1.0
# ...              ...     ...                   ...
# 136254         35-44   149.0                   0.0
# 136255         65-74    99.0                   6.0
# 136257         55-64   138.0                   2.0
# 136259         25-34    91.0                   2.0
# 136260         25-34   127.0                   2.0
#
#         tract_minority_pop_percent  interest_rate  loan_amount     loan_type  \
# 8                            24.00          4.500     345000.0  Conventional
# 16                           30.84          3.750     335000.0            VA
# 17                           46.45          3.990     225000.0            VA
# ...

# %%
data = data[data["loan_type"].str.contains("FHA")==False]

# %%
data = data[data["loan_type"].str.contains("FSA")==False]

# %%
data.head()
# Out:
#    applicant_age  income  debt_to_income_ratio  tract_minority_pop_percent  \
# 8          25-34   157.0                   0.0                       24.00
# 16         45-54   145.0                   1.0                       30.84
# 17         35-44   105.0                   1.0                       46.45
# 18         25-34   142.0                   2.0                       32.84
# 19         25-34   165.0                   1.0                       94.53
#
#     interest_rate  loan_amount     loan_type  property_value  \
# 8            4.50     345000.0  Conventional        365000.0
# 16           3.75     335000.0            VA        365000.0
# 17           3.99     225000.0            VA        235000.0
# 18           3.75     405000.0            VA        395000.0
# 19           4.25     375000.0            VA        375000.0
#
#     total_loan_costs  accepted  ...  2 or more minority races  \
# 8            3759.92       1.0  ...                         0
# ...

# %%
encode_binary_variable(data, "loan_type", "Conventional", "VA")

# %%
data.head()
# Out:
#     applicant_age  income  debt_to_income_ratio  tract_minority_pop_percent  \
# 8             0.0   157.0                   0.0                       24.00
# 16            1.0   145.0                   1.0                       30.84
# 17            2.0   105.0                   1.0                       46.45
# 18            0.0   142.0                   2.0                       32.84
# 19            0.0   165.0                   1.0                       94.53
#
#     interest_rate  loan_amount  loan_type  property_value  total_loan_costs  \
# 8            4.50     345000.0          0        365000.0           3759.92
# 16           3.75     335000.0          1        365000.0           9047.48
# 17           3.99     225000.0          1        235000.0           6208.58
# 18           3.75     405000.0          1        395000.0          20143.41
# 19           4.25     375000.0          1        375000.0           1562.31
#
# ...

# %%
data['applicant_age'].unique()
# Out:
# array(['25-34', '45-54', '35-44', '55-64', '>74', '65-74', '<25'],
#       dtype=object)

# %%
applicant_age_sort = ['25-34', '45-54', '35-44', '55-64', '>74', '65-74', '<25']
applicant_age_enc = OrdinalEncoder(categories=[applicant_age_sort])
data['applicant_age'] = applicant_age_enc.fit_transform(data['applicant_age'].values.reshape(-1, 1))

# %%
data.head()
# Out:
#     applicant_age  income  debt_to_income_ratio  tract_minority_pop_percent  \
# 8             0.0   157.0                   0.0                       24.00
# 16            1.0   145.0                   1.0                       30.84
# 17            2.0   105.0                   1.0                       46.45
# 18            0.0   142.0                   2.0                       32.84
# 19            0.0   165.0                   1.0                       94.53
#
#     interest_rate  loan_amount  loan_type  property_value  total_loan_costs  \
# 8            4.50     345000.0          0        365000.0           3759.92
# 16           3.75     335000.0          1        365000.0           9047.48
# 17           3.99     225000.0          1        235000.0           6208.58
# 18           3.75     405000.0          1        395000.0          20143.41
# 19           4.25     375000.0          1        375000.0           1562.31
#
# ...

# %%
from sklearn.model_selection import train_test_split
data = data.drop(['Couple'],axis=1)

# %%
X = data.drop(labels=["loan_type"], axis=1)
y = data["loan_type"]

# %%
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=0.2, random_state=0)

# %% [markdown]
# # Logistic regression model

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression(random_state=1, max_iter=1000)

# %%
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=1)

# %%
y_pred = logreg.predict(X_val)

# %% [markdown]
# # Model Performance

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
print("Accuracy: ", accuracy_score(y_val, y_pred))
# Out:
# Accuracy:  0.930370942812983

# %%
print("Precision for government backed Applications: ", precision_score(y_val, y_pred, pos_label=0))
print("Recall for government backed Applications: ", recall_score(y_val, y_pred, pos_label=0))
# Out:
# Precision for government backed Applications:  0.9324163154965414
# Recall for government backed Applications:  0.9956698930208864

# %% [markdown]
# # F1 Score

# %%
from sklearn.metrics import f1_score

# %%
print("F1 Score for the Baseline Model (Government backed): ", f1_score(y_val, y_pred, pos_label=0))
# Out:
# F1 Score for the Baseline Model (Government backed):  0.9630055430096489
